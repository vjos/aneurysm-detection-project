# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib ipympl
import numpy as np
import os
from intra import IntrA, load_pointcloud
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import proj3d

dataset = IntrA("~/Documents/Datasets/IntrA", dataset="generated")
it = iter(dataset)
pcld, label = next(it)

fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot(111, projection='3d')
plt.axis('off')

ax.scatter(pcld[:, 0], pcld[:, 1], pcld[:, 2], s=5, c='r', edgecolors='grey')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = IntrA("~/Documents/Datasets/IntrA", dataset="complete", npoints=5096)
it = iter(dataset)
pcld, label = next(it)

fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot(111, projection='3d')
plt.axis('off')

ax.scatter(pcld[:, 0], pcld[:, 1], pcld[:, 2], s=5, c='r', edgecolors='grey')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset = IntrA("~/Documents/Datasets/IntrA", dataset="annotated", npoints=5096)
it = iter(dataset)
pcld, label = next(it)

fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot(111, projection='3d')
plt.axis('off')

an = pcld[pcld[:, 3] > 0]
ve = pcld[pcld[:, 3] == 0]
ax.scatter(an[:, 0], an[:, 1], an[:, 2], s=5, c='r', edgecolors='grey')
ax.scatter(ve[:, 0], ve[:, 1], ve[:, 2], s=5, c='b', edgecolors='grey')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
